# %% [markdown]
# Data Collection -
#
#
#
#           1. Kaggle
#
#           2. UCI Machine learning Repo.
#
#           3. Google dataset research

# %% [markdown]
# API - Application Programming interface

# %%
# getting the data through API
# installing Kaggle Library
# !pip install kaggle

# %% [markdown]
# Upload your Kaggle.json file

# %%
# configuring the path of Kaggle.json
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# importing the earthquake data set
# Api to fetch data set from kaggle
# !kaggle competitions download -c LANL-Earthquake-Prediction
# Out:
# LANL-Earthquake-Prediction.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# extracting the compressed Data set
from zipfile import ZipFile
dataset = '/content/LANL-Earthquake-Prediction.zip'
with ZipFile(dataset,'r') as zip :
  zip.extractall()
  print('The dataset is extracted')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-5f80a36ee803> in <cell line: 4>()
#       3 dataset = '/content/LANL-Earthquake-Prediction.zip'
#       4 with ZipFile(dataset,'r') as zip :
# ----> 5   zip.extractall()
#       6   print('The dataset is extracted')
#
# /usr/lib/python3.10/zipfile.py in extractall(self, path, members, pwd)
#    1658
#    1659         for zipinfo in members:
# -> 1660             self._extract_member(zipinfo, path, pwd)
#    1661
#    1662     @classmethod
#
# /usr/lib/python3.10/zipfile.py in _extract_member(self, member, targetpath, pwd)
#    1713         with self.open(member, pwd=pwd) as source, \
#    1714              open(targetpath, "wb") as target:
# -> 1715             shutil.copyfileobj(source, target)
#    1716
#    1717         return targetpath
#
# /usr/lib/python3.10/shutil.py in copyfileobj(fsrc, fdst, length)
# ...
