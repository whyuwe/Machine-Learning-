# %% [markdown]
# # EDA

# %% [markdown]
# Unvirate Analysis

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dataset\\train.csv')

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# 1. Categorial Data

# %% [markdown]
# a. Countplot - define the frequency of Outcome

# %%
#countplot
#sns.countplot(df['Survived'])
df['Survived'].value_counts().plot(kind ='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
sns.countplot(df['Embarked'])
# Out:
# <Axes: xlabel='count', ylabel='Embarked'>

# %% [markdown]
# b. Piechart

# %%
data = df['Survived'].value_counts()
plt.pie(df, labels= df.index ,autopct = "%.2f",startangle= 90, colors =['skyblue','pink'] )

# %% [markdown]
# 2. Numerical Data

# %% [markdown]
#   a.  Histogram

# %%
plt.hist(df['Age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# b. Distplot

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_11628\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# C. BoxPlot

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
df['Age'].skew()
# Out:
# 0.38910778230082704

# %% [markdown]
# # Bivarate and Mulitvarate Analaysis

# %%
titanic = pd.read_csv('dataset\\train.csv')
iris = pd.read_csv('dataset\iris_data.csv')
placement = pd.read_csv('dataset\placement.csv')

# %%
placement.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %% [markdown]
# 1. ScatterPlot (Numerical -Numerical)

# %%
sns.scatterplot(x ='cgpa',y ='package',hue =None , data = placement)
plt.title('Scatterplot')
# Out:
# Text(0.5, 1.0, 'Scatterplot')

# %% [markdown]
# # 2. Bar PLot (Numerical - Categorical)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# titanic dataset
sns.barplot( x ='Survived',y = 'Age' ,hue = 'Sex' ,data = titanic )
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %% [markdown]
# # 3. Boxplot (Numerical - Categorical)

# %%
sns.boxplot(x ='Age',y = 'Sex',data = titanic,hue ='Survived')
# Out:
# <Axes: xlabel='Age', ylabel='Sex'>

# %% [markdown]
# # 4. Distplot (Numerical - categorical)

# %%
sns.distplot(titanic[titanic['Survived']==0]['Age'],hist =False)
sns.distplot(titanic[titanic['Survived']==1]['Age'],hist =False)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_11628\2009207810.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic['Survived']==0]['Age'],hist =False)
# C:\Users\dell\AppData\Local\Temp\ipykernel_11628\2009207810.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# # 5. HeatMap(Categorical- Categorical)

# %%
sns.heatmap(pd.crosstab(titanic['Pclass'],titanic ['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
#titanic.groupby('Pclass').mean()['Survived']*100

# %% [markdown]
# # 6. ClusterMap(Categorical -Categorical)

# %%
sns.clustermap(pd.crosstab(titanic['SibSp'],titanic['Survived']))

# %% [markdown]
# # 7.PairPlot

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.pairplot(data =iris, hue = 'Species')

# %% [markdown]
# # 8. LinePlot

# %%
placement.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
placement.groupby('cgpa').sum().reset_index
# Out:
# <bound method DataFrame.reset_index of       package
# cgpa
# 4.26     1.53
# 4.57     1.94
# 4.73     1.48
# 4.79     1.48
# 4.85     1.54
# ...       ...
# 9.16     4.25
# 9.26     3.79
# 9.31     4.37
# 9.38     4.02
# 9.58     4.43
#
# [163 rows x 1 columns]>

# %%
sns.lineplot(x ='cgpa',y ='package' ,data =placement)
# Out:
# <Axes: xlabel='cgpa', ylabel='package'>
